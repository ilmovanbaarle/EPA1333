# %% [markdown]
# ## Final Assignment
#
# Country rating scheme

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy import array
from numpy import NaN
plt.style.use('ggplot')

# %%
co2 = pd.read_csv("API_EN.ATM.CO2E.KT_DS2_en_csv_v2_315941.csv", sep=',', skipinitialspace=True, skiprows=4, index_col=1)

# %%
co2.head()
# Out:
#              Country Name      Indicator Name  Indicator Code      1960  \
# Country Code
# ABW                 Aruba  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
# AFG           Afghanistan  CO2 emissions (kt)  EN.ATM.CO2E.KT   414.371
# AGO                Angola  CO2 emissions (kt)  EN.ATM.CO2E.KT   550.050
# ALB               Albania  CO2 emissions (kt)  EN.ATM.CO2E.KT  2024.184
# AND               Andorra  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
#
#                   1961      1962      1963      1964      1965      1966  ...  \
# Country Code                                                              ...
# ABW                NaN       NaN       NaN       NaN       NaN       NaN  ...
# AFG            491.378   689.396   707.731   839.743  1008.425  1092.766  ...
# AGO            454.708  1180.774  1151.438  1224.778  1188.108  1554.808  ...
# ALB           2280.874  2464.224  2082.856  2016.850  2174.531  2552.232  ...
# ...
